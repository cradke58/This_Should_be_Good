# %%
# !pip install pandas dash


# In[10]:


# Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px
import plotly.graph_objects as go

# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = dash.Dash(__name__)

# Create an app layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dashboard',
            style={'textAlign': 'center', 'color': '#503D36', 'font-size': 40}),
            
    # TASK 1: Add a dropdown list to enable Launch Site selection
    # The default select value is for ALL sites
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
        ],
        value='ALL',
        placeholder="Select a Launch Site here",
        searchable=True,
    ),
    
    html.Br(),

    # TASK 2: Add a pie chart to show the total successful launches count for all sites
    # If a specific launch site was selected, show the Success vs. Failed counts for the site
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),
    
    # TASK 3: Add a slider to select payload range
    dcc.RangeSlider(
        id='payload-slider',
        min=min_payload,
        max=max_payload,
        step=1000,
        marks={str(payload): str(payload) for payload in range(int(min_payload), int(max_payload)+1, 1000)},
        value=[min_payload, max_payload]
    ),

    # TASK 4: Add a scatter chart to show the correlation between payload and launch success
    html.Div(dcc.Graph(id='success-payload-scatter-chart')),
])
# Define the callback function
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'),
     Input(component_id='payload-slider', component_property='value')]
)
def update_scatter_chart(selected_site, selected_payload_range):
    # Check if ALL sites were selected or just a specific launch site
    if selected_site == 'ALL':
        filtered_df = spacex_df # No filtering needed for 'ALL' sites
    else:
        # Filter the spacex_df for the selected launch site
        filtered_df = spacex_df[spacex_df['Launch Site'] == selected_site]
    
    # Filter the filtered_df based on the selected payload range
    filtered_df = filtered_df[
        (filtered_df['Payload Mass (kg)'] >= selected_payload_range[0]) &
        (filtered_df['Payload Mass (kg)'] <= selected_payload_range[1])
    ]
    
    # Create the scatter plot
    fig = px.scatter(
        data_frame=filtered_df,
        x='Payload Mass (kg)',
        y='class',
        color='Booster Version Category',
        title='Payload vs Class with Booster Version Category'
    )
    
    return fig

# Callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(
    Output('success-pie-chart', 'figure'),
    Input('site-dropdown', 'value')
)
def update_pie_chart(selected_site):
    if selected_site == 'ALL':
        # Calculate success rates for all launch sites
        success_rates = spacex_df.groupby('Launch Site')['class'].mean()

        fig = go.Figure(data=[go.Pie(labels=success_rates.index, values=success_rates.values)])
        # fig.update_layout(title='Success Rate for All Launch Sites')

        return fig
    else:
        selected_df = spacex_df[spacex_df['Launch Site'] == selected_site]
        success_count = selected_df[selected_df['class'] == 1]['class'].count()
        failed_count = selected_df[selected_df['class'] == 0]['class'].count()
        labels = ['Success', 'Failed']
        values = [success_count, failed_count]

        fig = go.Figure(data=[go.Pie(labels=labels, values=values)])
        return fig

# Callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output

# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Requirement already satisfied: pandas in c:\users\cradk\anaconda3\envs\course\lib\site-packages (2.0.3)
# Requirement already satisfied: dash in c:\users\cradk\anaconda3\envs\course\lib\site-packages (2.13.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: nest-asyncio in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from dash) (1.5.6)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from dash) (5.17.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from dash) (4.4.0)
# Requirement already satisfied: retrying in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from dash) (2.2.5)
# Requirement already satisfied: ansi2html in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from dash) (1.8.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: setuptools in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from dash) (65.6.3)
# Requirement already satisfied: requests in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from dash) (2.31.0)
# Requirement already satisfied: Werkzeug<2.3.0 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (6.8.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: packaging in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from plotly>=5.0.0->dash) (23.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from plotly>=5.0.0->dash) (8.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from Werkzeug<2.3.0->dash) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from requests->dash) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from requests->dash) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from requests->dash) (3.2.0)
# Requirement already satisfied: colorama in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from click>=8.0->Flask<2.3.0,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\cradk\anaconda3\envs\course\lib\site-packages (from importlib-metadata>=3.6.0->Flask<2.3.0,>=1.0.4->dash) (3.11.0)
# C:\Users\cradk\AppData\Local\Temp\ipykernel_11988\3450346536.py:10: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# C:\Users\cradk\AppData\Local\Temp\ipykernel_11988\3450346536.py:11: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
